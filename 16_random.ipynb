# %%
import random

# %%
value = random.random()
print(value)
# Out:
# 0.29279815442796453

# %%
random.uniform(1,10)
# Out:
# 5.72021700953508

# %%
value = random.randint(1,10)
value
# Out:
# 4

# %%
colors = ["black","red","orange"]
random.choices(colors,weights=[4,4,1],k = 10)
# Out:
# ['orange',
#  'black',
#  'red',
#  'black',
#  'black',
#  'black',
#  'red',
#  'red',
#  'red',
#  'orange']

# %%
my_list = list(range(1,53))

# %%
random.shuffle(my_list)

# %%
my_list
# Out:
# [31,
#  44,
#  27,
#  45,
#  6,
#  14,
#  33,
#  9,
#  10,
#  11,
#  34,
#  48,
#  39,
#  38,
#  35,
#  7,
#  42,
#  12,
#  2,
#  23,
#  37,
#  36,
#  32,
#  21,
#  49,
#  30,
#  24,
#  8,
#  25,
#  1,
#  5,
#  40,
#  26,
#  41,
#  50,
#  13,
#  17,
#  15,
#  4,
#  46,
#  28,
#  29,
#  47,
#  22,
#  52,
#  19,
#  43,
#  3,
#  20,
#  51,
#  18,
#  16]
