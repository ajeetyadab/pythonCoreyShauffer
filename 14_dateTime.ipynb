# %%
import datetime

# %%
td = datetime.date(2016,7,24)

# %%
print(td)
# Out:
# 2016-07-24

# %%
tday = datetime.date.today()

# %%
print(tday)
# Out:
# 2026-06-30

# %%
print(tday.year)
# Out:
# 2026

# %%
tday.weekday()
# Out:
# 1

# %%
tday.isoweekday()
# Out:
# 2

# %% [markdown]
# ### time delta

# %%
tdelta = datetime.timedelta(7)

# %%
print(tdelta)
# Out:
# 7 days, 0:00:00

# %%
print(tday + tdelta)
# Out:
# 2026-07-07

# %%
print(tday - tdelta)
# Out:
# 2026-06-23

# %%
print(tday-td)
# Out:
# 3628 days, 0:00:00

# %% [markdown]
# #### calculating age

# %%
birth_date = datetime.date(1988,7,5)

# %%
tday = datetime.date.today()

# %%
age = tday- birth_date
print(age)
# Out:
# 13874 days, 0:00:00

# %%
age.days//365
# Out:
# 38

# %%
age.days%365
# Out:
# 4

# %%
start_year = 1988
current_year = datetime.datetime.today().year

# %%
leap_year_since_your_birthdays = []
for i in range(start_year,current_year+1):
    if( i % 4 ==0 and i % 100 !=0) or ( i % 400 ==0):
        leap_year_since_your_birthdays.append(i)

# %%
leap_year_since_your_birthdays
# Out:
# [1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024]

# %%
count = sum(
    1
    for year in range(start_year,current_year+1)
    if(year % 4 == 0 and year % 100 !=0) or (year % 400 ==0)
)

# %%
count
# Out:
# 10

# %%
result = [1 for year in range(start_year,current_year+1) if(year % 4 == 0 and year % 100 !=0) or (year % 400 ==0)]

# %%
sum(result)
# Out:
# 10

# %%
t = datetime.time(9,30,45,100000)

# %%
t.hour
# Out:
# 9

# %%
dt = datetime.datetime(2016,7,26,12,30,45,100000)

# %%
tdelta =  datetime.timedelta(12)

# %%
print(dt+tdelta)
# Out:
# 2016-08-07 12:30:45.100000

# %%
dt_today = datetime.datetime.today()
dt_now = datetime.datetime.today()
dt_utcnow = datetime.datetime.utcnow()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13864\2277205368.py:3: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   dt_utcnow = datetime.datetime.utcnow()

# %%
print(dt_utcnow)
# Out:
# 2026-06-30 07:53:49.368169

# %%
! py -m pip install pytz

# %% [markdown]
# ### pytz module

# %%
import pytz

# %%
dt = datetime.datetime(2016,7,27,12,30,45,tzinfo =pytz.UTC )

# %%
print(dt)
# Out:
# 2016-07-27 12:30:45+00:00

# %%
print(datetime.datetime.now(tz = pytz.UTC))
# Out:
# 2026-06-30 07:53:51.543825+00:00

# %%
print(datetime.datetime.now())
# Out:
# 2026-06-30 13:23:52.063479

# %%
dt_utcnow = datetime.datetime.utcnow().replace(tzinfo = pytz.UTC)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13864\397145766.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   dt_utcnow = datetime.datetime.utcnow().replace(tzinfo = pytz.UTC)

# %%
print(dt_utcnow)
# Out:
# 2026-06-30 07:53:52.336079+00:00

# %%
dt_mtn = dt_utcnow.astimezone(pytz.timezone("US/Mountain"))

# %%
print(dt_mtn)
# Out:
# 2026-06-30 01:53:52.336079-06:00

# %%
dt_asia = dt_utcnow.astimezone(pytz.timezone("Asia/Kolkata"))

# %%
print(dt_asia)
# Out:
# 2026-06-30 13:23:52.336079+05:30

# %%
for tz in pytz.all_timezones:
    print(tz)
# Out:
# Africa/Abidjan
# Africa/Accra
# Africa/Addis_Ababa
# Africa/Algiers
# Africa/Asmara
# Africa/Asmera
# Africa/Bamako
# Africa/Bangui
# Africa/Banjul
# Africa/Bissau
# Africa/Blantyre
# Africa/Brazzaville
# Africa/Bujumbura
# Africa/Cairo
# Africa/Casablanca
# Africa/Ceuta
# Africa/Conakry
# Africa/Dakar
# Africa/Dar_es_Salaam
# Africa/Djibouti
# Africa/Douala
# Africa/El_Aaiun
# Africa/Freetown
# Africa/Gaborone
# Africa/Harare
# Africa/Johannesburg
# Africa/Juba
# Africa/Kampala
# Africa/Khartoum
# Africa/Kigali
# Africa/Kinshasa
# Africa/Lagos
# Africa/Libreville
# Africa/Lome
# Africa/Luanda
# Africa/Lubumbashi
# Africa/Lusaka
# Africa/Malabo
# Africa/Maputo
# Africa/Maseru
# Africa/Mbabane
# Africa/Mogadishu
# Africa/Monrovia
# Africa/Nairobi
# Africa/Ndjamena
# Africa/Niamey
# Africa/Nouakchott
# Africa/Ouagadougou
# Africa/Porto-Novo
# Africa/Sao_Tome
# Africa/Timbuktu
# Africa/Tripoli
# Africa/Tunis
# Africa/Windhoek
# America/Adak
# America/Anchorage
# America/Anguilla
# ...

# %%
dt = datetime.datetime.now()
print(dt)
# Out:
# 2026-06-30 13:25:29.477236

# %%
dt_india = dt_mtn.astimezone(pytz.timezone("Asia/Kolkata"))

# %%
print(dt_india)
# Out:
# 2026-06-30 13:23:52.336079+05:30

# %%
dt_mountain = pytz.timezone("US/Mountain")

# %%
dt_india = datetime.datetime.now(tz = pytz.timezone("Asia/kolkata"))
print(dt_india.strftime("%B %d %Y"))
# Out:
# June 30 2026

# %%
print(dt)
# Out:
# 2026-06-30 13:25:29.477236

# %%
st_str = "June 30 2026"

# %%
dt = datetime.datetime.strptime(st_str,"%B %d %Y")

# %%
print(dt)
# Out:
# 2026-06-30 00:00:00
