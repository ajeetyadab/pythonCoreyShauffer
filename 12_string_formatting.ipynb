# %%
sentence = 'My name is {name} and I am {age} years old.'.format(name='Jen', age=
23)

# %%
sentence
# Out:
# 'My name is Jen and I am 23 years old.'

# %% [markdown]
# #### dictionary unpacking

# %%
person = {"name":"Jen","age":23}

# %%
person
# Out:
# {'name': 'Jen', 'age': 23}

# %%
sentence = "My name is {name} and i am {age} years old.".format(**person)

# %%
sentence
# Out:
# 'My name is Jen and i am 23 years old.'

# %%
for i in range(1,11):
    print("The number is {:03}".format(i))
# Out:
# The number is 001
# The number is 002
# The number is 003
# The number is 004
# The number is 005
# The number is 006
# The number is 007
# The number is 008
# The number is 009
# The number is 010

# %% [markdown]
# "{:fillalignwidth.type}"

# %%
pi = 3.14159265
large_value = 1000**2

# %%
print("Pi is {:.3f}".format(pi))
# Out:
# Pi is 3.142

# %%
print("value {:,.2f}".format(large_value))
# Out:
# value 1,000,000.00

# %% [markdown]
# ## date time

# %%
import datetime
my_date = datetime.datetime(2026,9,24,12,30,45)

# %%
sentence = "{:%B %d %Y %A }".format(my_date)

# %%
sentence
# Out:
# 'September 24 2026 Thursday '
